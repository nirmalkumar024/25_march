# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %%
plt.hist(df.Price)
# Out:
# (array([6.029e+03, 4.390e+03, 1.820e+02, 6.600e+01, 7.000e+00, 1.000e+00,
#         5.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1759. ,  9534.3, 17309.6, 25084.9, 32860.2, 40635.5, 48410.8,
#         56186.1, 63961.4, 71736.7, 79512. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10683, dtype: int64>

# %%
df['Price'].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10683, dtype: int64>

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
sns.scatterplot(x=df.Price,y=df.Airline)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

# %%
sns.scatterplot(x=df.Price,y=df.Airline)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %% [markdown]
# In this visualization seen that some outlier are present in  the dataset it is affect the price of the airlines, so we have to clear it then we get price of airlines good.

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?

# %%
sns.catplot(x="Price",y="Airline",data=df)

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?

# %% [markdown]
# I will use the feature that help me to visualize the data clear and understanding, mostly i prefer barchart for pick and bottom seen then check any outlier i prefer scatter plot.then i will visualiz wich one airline ask for money according to the distance of travel.

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# I will use the feature that help me to visualize the data clear and understanding, mostly i prefer barchart for pick and bottom seen then check any outlier i prefer scatter plot.then i will visualiz wich one airline ask for money according to the distance of travel.
#
# There are some factors which we can use in airline company:-
# 1.distance
# 2.class of boarding
# 3.Class of airline
# 4.traffic of pacenger on the boarding date

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
gl=pd.read_csv("Google_cleaned.csv")

# %%
gl.head(2)
# Out:
#    Unnamed: 0                                             App        Category  \
# 0         0.0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1         1.0                             Coloring book moana  ART_AND_DESIGN
#
#    Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 0     4.1    159.0  19000.0   10 000   Free    0.0       Everyone
# 1     3.9    967.0  14000.0  500 000   Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver   Day  \
# 0               Art & Design   07-01-2018       1.0.0  4.0.3 and up   7.0
# 1  Art & Design;Pretend Play   15-01-2018       2.0.0  4.0.3 and up  15.0
#
#    Month    Year
# 0    1.0  2018.0
# 1    1.0  2018.0

# %%
gl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      3062 non-null   float64
#  1   App             3062 non-null   object
#  2   Category        3062 non-null   object
#  3   Rating          2923 non-null   float64
#  4   Reviews         3062 non-null   float64
#  5   Size            2317 non-null   float64
#  6   Installs        3062 non-null   object
#  7   Type            3062 non-null   object
#  8   Price           3062 non-null   float64
#  9   Content Rating  3062 non-null   object
#  10  Genres          3062 non-null   object
#  11  Last Updated    3062 non-null   object
#  12  Current Ver     3060 non-null   object
#  13  Android Ver     3062 non-null   object
#  14  Day             3062 non-null   float64
#  15  Month           3062 non-null   float64
#  16  Year            3062 non-null   float64
# ...

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
sns.boxplot(gl.Rating)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %% [markdown]
# Yes there have some missing value present in the dataset so there have inaccurate value we find, so this issue resolve by the overfiting method and we can determine this issue by outliers and we have fix this issue by puting the value of mean and average point according the requirement.

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
sns.scatterplot(x=gl.App,y=gl.Size)
# Out:
# <AxesSubplot: xlabel='App', ylabel='Size'>
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 128214 (\N{OPEN BOOK}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 28459 (\N{CJK UNIFIED IDEOGRAPH-6F2B}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 21654 (\N{CJK UNIFIED IDEOGRAPH-5496}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 12304 (\N{LEFT BLACK LENTICULAR BRACKET}) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 12305 (\N{RIGHT BLACK LENTICULAR BRACKET}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %% [markdown]
# Yes, the price of app affect, it may be not sell as compare to other app, their some determine by their utility and using also affect the price and rating.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_csv(r"Google_cleaned.csv")
data.head()
df = pd.DataFrame(data)

name = df['App'].head(12)
price = df['Price'].head(12)

# Figure Size
fig = plt.figure(figsize =(10, 7))

# Horizontal Bar Plot
plt.bar(name[0:10], price[0:10])

# Show Plot
plt.show()

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
gl.App
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10835                                                  NaN
# 10836                                                  NaN
# 10837                                                  NaN
# 10838                                                  NaN
# 10839                                                  NaN
# Name: App, Length: 10840, dtype: object

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %%
 Loads the Google Play Store dataset from a CSV file and returns it as a DataFrame.

def load_google_play_store_data():

    # Define the URL of the dataset
    dataset_url = "Google_cleaned.csv"
    
    # Load the dataset into a pandas DataFrame
    playstore_df = pd.read_csv(dataset_url)
    
    return playstore_df

# Load the dataset and display the first few rows
google_play_data = load_google_play_store_data()
google_play_data.head()
# Out:
#   Cell In[23], line 1
#     Loads the Google Play Store dataset from a CSV file and returns it as a DataFrame.
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?
